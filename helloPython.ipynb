# %% [markdown]
# <a href="https://colab.research.google.com/github/de-Zest/python-ai-governance/blob/main/helloPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# Install the Google Generative AI library
# !{sys.executable} -m pip install google-generativeai

# %% [markdown]
# ### Recreate `helper_functions.py`
# This cell will create the `helper_functions.py` file with the necessary code to interact with the Gemini API.

# %%
# %%writefile helper_functions.py
import google.generativeai as genai
from google.colab import userdata

# Configure the API key directly.
# This assumes GOOGLE_API_KEY is set in Colab secrets.
try:
    GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=GOOGLE_API_KEY)
except Exception as e:
    print(f"Warning: Could not configure Gemini API. Error: {e}")
    print("Please ensure your GOOGLE_API_KEY is correctly set in Colab secrets and notebook access is enabled.")

gemini_model_for_helper = genai.GenerativeModel('models/gemini-flash-latest')

def print_llm_response(query):
    """Sends a query to the Gemini API and prints the response."""
    print(f"Sending query to Gemini API: {query}")
    try:
        response = gemini_model_for_helper.generate_content(query)
        print(f"LLM response: {response.text}")
    except Exception as e:
        print(f"Error generating content: {e}")
        print("Please ensure your GOOGLE_API_KEY is correctly set in Colab secrets and notebook access is enabled.")
# Out:
# Overwriting helper_functions.py

# %%
import importlib
import helper_functions # Ensure helper_functions is imported
importlib.reload(helper_functions) # Reload the module
from helper_functions import print_llm_response # Re-import the function

name = "Otto Matic"
dog_age = 21/7

print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might
entail in terms of energy level, interests, and behavior.""")
# Out:
# Sending query to Gemini API: If Otto Matic were a dog, he would be 3.0 years old.
# Describe what life stage that would be for a dog and what that might
# entail in terms of energy level, interests, and behavior.
# LLM response: If **Otto Matic** were a dog and had just reached the **3.0-year mark**, he would be entering the prime of his **Young Adulthood**.
#
# In canine terms, a three-year-old is roughly equivalent to a 28-to-30-year-old human. The chaotic "teenage" phase of puppyhood is in the rearview mirror, and he has officially settled into his permanent personality.
#
# Here is what life would look like for a 3-year-old Otto Matic:
#
# ### 1. The Life Stage: Young Adult Prime
# At three, a dog has reached full physical and mental maturity. For a hero like Otto, this is the "Sweet Spot." He is no longer growing in size, and his joints and muscles are at their peak athletic performance.
# ...

# %% [markdown]
# ### Scenario: Brave Astronaut Cat and Moon Cheese
#
# Let's imagine a daring astronaut cat on a lunar mission, discovering an entirely new kind of cheese.

# %%
astronaut_name = "Captain Whiskers"
lunar_location = "Crater of Deliciousness"
cheese_type = "Cosmic Cheddar"

print_llm_response(f"""Write a short, whimsical story about {astronaut_name}, an astronaut cat, who lands on the moon, specifically in the {lunar_location}. Describe the discovery of a new type of cheese called {cheese_type} and the cat's hilarious reaction.""")
# Out:
# Sending query to Gemini API: Write a short, whimsical story about Captain Whiskers, an astronaut cat, who lands on the moon, specifically in the Crater of Deliciousness. Describe the discovery of a new type of cheese called Cosmic Cheddar and the cat's hilarious reaction.
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 36221.34ms
# LLM response: Captain Whiskers was not your average tabby. While other cats were content chasing laser pointers in suburban living rooms, Whiskers was currently adjusting his pressurized tail-sleeve and staring out the viewport of the *S.S. Meow-tainer*.
#
# "One small step for cat," Whiskers meowed into his comms-unit, which mostly just translated his thoughts into rhythmic purring for Ground Control, "one giant leap for feline-kind."
#
# ...

# %%
print_llm_response("What is the capital of Nigeria?")
# Out:
# Sending query to Gemini API: What is the capital of Nigeria?
# LLM response: The capital of Nigeria is <strong>Abuja</strong>. It officially replaced Lagos as the capital on December 12, 1991.

# %% [markdown]
# ### Verify GOOGLE_API_KEY
# This cell will confirm that your `GOOGLE_API_KEY` is successfully configured in Colab secrets.

# %%
from google.colab import userdata

try:
    api_key = userdata.get('GOOGLE_API_KEY')
    if api_key:
        print("GOOGLE_API_KEY found in Colab secrets. You are all set!")
    else:
        print("GOOGLE_API_KEY not found or is empty in Colab secrets. Please ensure it's set correctly.")
except Exception as e:
    print(f"An error occurred while trying to access GOOGLE_API_KEY: {e}")
    print("Please ensure you have enabled notebook access to secrets.")
# Out:
# GOOGLE_API_KEY found in Colab secrets. You are all set!

# %% [markdown]
# ### Test `print_llm_response`
# This cell will import the `print_llm_response` function from the newly created file and test it.

# %%
import importlib
import helper_functions  # Import the module directly

# Reload the helper_functions module to ensure the latest version is used
importlib.reload(helper_functions)

# Re-import the updated function
from helper_functions import print_llm_response

# Define the variables for the story query
driver = "unicorn"
driver_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# Test with the new query
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing\na {driver_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# Sending query to Gemini API: Write me a 300 word children's story about a unicorn racing
# a colorful, asymmetric dinosaur car for the Pluto champion cup.
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1321.35ms
# Error generating content: 404 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
# Please ensure your GOOGLE_API_KEY is correctly set in Colab secrets and notebook access is enabled.

# %%
import google.generativeai as genai

for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
# This is an example of code with multiple
# comments, including this one which
# spans multiple lines
print("Hello, Steve!")
# Follow up with an additional print command
print("How is your day going?")
print("What time is your flight to Ottawa?")
# Out:
# Hello, Steve!
# How is your day going?
# What time is your flight to Ottawa?

# %%
# This is an example of code with multiple
# comments, including this one which
# spans multiple lines
print("Hello, Steve!")
# Follow up with an additional print command
print("How is your day going?")
print("What time is your flight to Ottawa?")
# Out:
# Hello, Steve!
# How is your day going?
# What time is your flight to Ottawa?

# %%
from helper_functions import print_llm_response
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4910/1624274876.py in <cell line: 0>()
# ----> 1 from helper_functions import print_llm_response
#
# ModuleNotFoundError: No module named 'helper_functions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
